# %% [markdown]
# ###  Read CSV

# %%
import pandas as pd
import numpy as np

# %%
loandata = pd.read_csv('loan_datawithoutnull.csv')

# %%
loandata
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# 5    LP001024    Male     Yes          2      Graduate            No
# 6    LP001029    Male      No          0      Graduate            No
# 7    LP001030    Male     Yes          2      Graduate            No
# 8    LP001032    Male      No          0      Graduate            No
# 9    LP001036  Female      No          0      Graduate            No
# 10   LP001038    Male     Yes          0  Not Graduate            No
# 11   LP001043    Male     Yes          0  Not Graduate            No
# 12   LP001047    Male     Yes          0  Not Graduate            No
# ...

# %%
loandata.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Predicte **Loan_Status**

# %% [markdown]
# **About the loan_data.csv file:**
#
#
# * Loan_ID: A unique loan ID.
# * Gender: Either male or female.
# * Married: Weather Married(yes) or Not Marttied(No).
# * Dependents: Number of persons depending on the client.
# * Education: Applicant Education(Graduate or Undergraduate).
# * Self_Employed: Self-employed (Yes/No).
# * ApplicantIncome: Applicant income.
# * CoapplicantIncome: Co-applicant income.
# * LoanAmount: Loan amount in thousands.
# * Loan_Amount_Term: Terms of the loan in months.
# * Credit_History: Credit history meets guidelines.
# * Property_Area: Applicants are living either Urban, Semi-Urban or Rural.
# * Loan_Status: Loan approved (Y/N).

# %%
loandata.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# Converting string labels into numbers (Import LabelEncoder)

# %%
# Import LabelEncoder
from sklearn import preprocessing

#creating labelEncoder
number = preprocessing.LabelEncoder()

loandata['Gender'] = number.fit_transform(loandata['Gender'])
loandata['Married'] = number.fit_transform(loandata['Married'])
loandata['Dependents'] = number.fit_transform(loandata['Dependents'])
loandata['Education'] = number.fit_transform(loandata['Education'])
loandata['Self_Employed'] = number.fit_transform(loandata['Self_Employed'])
loandata['Property_Area'] = number.fit_transform(loandata['Property_Area'])

print(loandata)
# Out:
#       Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    LP001003       1        1           1          0              0
# 1    LP001005       1        1           0          0              1
# 2    LP001006       1        1           0          1              0
# 3    LP001008       1        0           0          0              0
# 4    LP001013       1        1           0          1              0
# 5    LP001024       1        1           2          0              0
# 6    LP001029       1        0           0          0              0
# 7    LP001030       1        1           2          0              0
# 8    LP001032       1        0           0          0              0
# 9    LP001036       0        0           0          0              0
# 10   LP001038       1        1           0          1              0
# 11   LP001043       1        1           0          1              0
# 12   LP001047       1        1           0          1              0
# ...

# %% [markdown]
# sklearn library, which can be found in sklearn.naive_bayes:
#
# sklearn.naive_bayes.CategoricalNB:
#     for using Naive Bayes on categorical predictor variables.
#
# sklearn.naive_bayes.GaussianNB:
#     for Naive Bayes on numerical predictor variables, with the assumption
#     that these variables follow Gaussian distribution.
#
# sklearn.naive_bayes.MultinomialNB:
#     the predictor variables represent the counts, a popular application
#     is in text classification. Fractional counts like tf-idf may also work.
#
# sklearn.naive_bayes.ComplementNB:
#     A modification of MultinomialNB which is suitable for imbalanced datasets.
#
# sklearn.naive_bayes.BernoulliNB:
#     assumes the data follows Bernoulli distribution (i.e. possible values of
#     predictor variables are 0 and 1).

# %% [markdown]
# ## NEW DATA SET

# %%
# List ที่มี dict
newdata = [{'Gender': 1, 'Married': 1, 'Dependents': 0, 'Education': 1, 'Self_Employed': 0, 'ApplicantIncome': 3095, 'CoapplicantIncome': 0.0, 'LoanAmount': 113.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 1}, 
           {'Gender': 0, 'Married': 1, 'Dependents': 0, 'Education': 1, 'Self_Employed': 0, 'ApplicantIncome': 3400, 'CoapplicantIncome': 3541.0, 'LoanAmount': 120.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 1}, 
         {'Gender': 1, 'Married': 1, 'Dependents': 3, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 3691, 'CoapplicantIncome': 1666.0, 'LoanAmount': 112.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 1}, 
           {'Gender': 1, 'Married': 0, 'Dependents': 2, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 6500, 'CoapplicantIncome': 0.0, 'LoanAmount': 125.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 0}, 
        {'Gender': 1, 'Married': 1, 'Dependents': 0, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 3033, 'CoapplicantIncome': 1668.0, 'LoanAmount': 130.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 0.0, 'Property_Area': 1}, 
           {'Gender': 1, 'Married': 0, 'Dependents': 2, 'Education': 1, 'Self_Employed': 0, 'ApplicantIncome': 2060, 'CoapplicantIncome': 0.0, 'LoanAmount': 95.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 2}, 
         {'Gender': 0, 'Married': 0, 'Dependents': 0, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 4230, 'CoapplicantIncome': 1522.0, 'LoanAmount': 100.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 0}, 
           {'Gender': 1, 'Married': 0, 'Dependents': 0, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 2708, 'CoapplicantIncome': 2336.0, 'LoanAmount': 141.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 2}, 
         {'Gender': 1, 'Married': 1, 'Dependents': 3, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 1299, 'CoapplicantIncome': 1483.0, 'LoanAmount': 80.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 1}, 
           {'Gender': 1, 'Married': 1, 'Dependents': 0, 'Education': 0, 'Self_Employed': 0, 'ApplicantIncome': 8750, 'CoapplicantIncome': 0.0, 'LoanAmount': 100.0, 'Loan_Amount_Term': 360.0, 'Credit_History': 1.0, 'Property_Area': 2}
]
newdata
# Out:
# [{'Gender': 1,
#   'Married': 1,
#   'Dependents': 0,
#   'Education': 1,
#   'Self_Employed': 0,
#   'ApplicantIncome': 3095,
#   'CoapplicantIncome': 0.0,
#   'LoanAmount': 113.0,
#   'Loan_Amount_Term': 360.0,
#   'Credit_History': 1.0,
#   'Property_Area': 1},
#  {'Gender': 0,
#   'Married': 1,
#   'Dependents': 0,
#   'Education': 1,
#   'Self_Employed': 0,
#   'ApplicantIncome': 3400,
#   'CoapplicantIncome': 3541.0,
#   'LoanAmount': 120.0,
#   'Loan_Amount_Term': 360.0,
#   'Credit_History': 1.0,
#   'Property_Area': 1},
#  {'Gender': 1,
#   'Married': 1,
#   'Dependents': 3,
#   'Education': 0,
#   'Self_Employed': 0,
#   'ApplicantIncome': 3691,
#   'CoapplicantIncome': 1666.0,
#   'LoanAmount': 112.0,
#   'Loan_Amount_Term': 360.0,
#   'Credit_History': 1.0,
#   'Property_Area': 1},
#  {'Gender': 1,
#   'Married': 0,
#   'Dependents': 2,
#   'Education': 0,
#   'Self_Employed': 0,
#   'ApplicantIncome': 6500,
#   'CoapplicantIncome': 0.0,
#   'LoanAmount': 125.0,
# ...

# %%
type(newdata)
# Out:
# list

# %%
len(newdata)
# Out:
# 10

# %%
test = list(newdata[0].values())
print(test)
# Out:
# [1, 1, 0, 1, 0, 3095, 0.0, 113.0, 360.0, 1.0, 1]

# %%
print(type(test))
print(len(test))
# Out:
# <class 'list'>
# 11

# %%
allLoanList = []

# %%
for i in range(len(newdata)):
    allLoanList.append(list(newdata[i].values()))

# %%
print(allLoanList)
print(len(allLoanList))
# Out:
# [[1, 1, 0, 1, 0, 3095, 0.0, 113.0, 360.0, 1.0, 1], [0, 1, 0, 1, 0, 3400, 3541.0, 120.0, 360.0, 1.0, 1], [1, 1, 3, 0, 0, 3691, 1666.0, 112.0, 360.0, 1.0, 1], [1, 0, 2, 0, 0, 6500, 0.0, 125.0, 360.0, 1.0, 0], [1, 1, 0, 0, 0, 3033, 1668.0, 130.0, 360.0, 0.0, 1], [1, 0, 2, 1, 0, 2060, 0.0, 95.0, 360.0, 1.0, 2], [0, 0, 0, 0, 0, 4230, 1522.0, 100.0, 360.0, 1.0, 0], [1, 0, 0, 0, 0, 2708, 2336.0, 141.0, 360.0, 1.0, 2], [1, 1, 3, 0, 0, 1299, 1483.0, 80.0, 360.0, 1.0, 1], [1, 1, 0, 0, 0, 8750, 0.0, 100.0, 360.0, 1.0, 2]]
# 10

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# #### Import Library of Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB

# %%
loandata.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ### GaussianNB

# %%
NB_model = GaussianNB()

# Train the model using the training sets
NB_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= NB_model.predict(allLoanList)
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y']

# %% [markdown]
# ### BernoulliNB

# %%
NB_model = BernoulliNB()

# Train the model using the training sets
NB_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= NB_model.predict(allLoanList)
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y']

# %% [markdown]
# ### MultinomialNB

# %%
NB_model = MultinomialNB()

# Train the model using the training sets
NB_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= NB_model.predict(allLoanList)
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'N' 'N' 'Y' 'N' 'Y' 'Y' 'N' 'N' 'Y']

# %% [markdown]
# ### K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# #### n_neighbors=3

# %%
#Create a KNN Classifier
KNN_model = KNeighborsClassifier(n_neighbors= 3)

KNN_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= KNN_model.predict(allLoanList) # 1:rain, 1:hot, 0:high, 1:weak
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y']

# %% [markdown]
# #### n_neighbors=5

# %%
#Create a KNN Classifier
KNN_model = KNeighborsClassifier(n_neighbors= 5)


KNN_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= KNN_model.predict(allLoanList)
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'Y' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'Y' 'Y']

# %% [markdown]
# #### n_neighbors=7

# %%
#Create a KNN Classifier
KNN_model = KNeighborsClassifier(n_neighbors= 7)

KNN_model.fit(loandata[['Gender', 'Married', 'Dependents', 'Education','Self_Employed', 'ApplicantIncome', 
                       'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term', 'Credit_History', 'Property_Area']] 
            , loandata['Loan_Status'])

#Predict Output
predicted= KNN_model.predict(allLoanList)
print("Predicted Value:", predicted)
# Out:
# Predicted Value: ['Y' 'Y' 'Y' 'N' 'Y' 'N' 'Y' 'Y' 'Y' 'Y']
