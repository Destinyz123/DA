# %% [markdown]
# # รหัสนักศึกษา-ชื่อ-นามสกุล (Heading)

# %% [markdown]
# ### ในการทำแบบฝึกหัดให้เพิ่ม cell ด้านล่างของโจทย์เพื่อเขียน code

# %% [markdown]
# import Library ที่สำคัญในงาน

# %%
#Import Python Libraries
import numpy as np
# import scipy as sp
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# # dataset : https://github.com/King-Ju/datasetforstudent/blob/8405aba6740d992cb55f546d3740e1733f5f8fcb/starbucks.csv

# %% [markdown]
# 1. Read csv file (".csv")

# %%
#Read csv file

#df = pd.read_csv("E:/520215/Salaries.csv")

# %% [markdown]
# 2. จงแสดงเคื่องดื่มประเภท Classic Espresso Drinks ที่มีส่วนประกอบของ Calories คือ 100 ,Total Carbohydrates (g) > 170

# %%
# Out:
#           Beverage_category                                  Beverage  \
# 13  Classic Espresso Drinks                               Caffè Latte
# 14  Classic Espresso Drinks                               Caffè Latte
# 26  Classic Espresso Drinks       Caffè Mocha (Without Whipped Cream)
# 37  Classic Espresso Drinks  Vanilla Latte (Or Other Flavoured Latte)
# 38  Classic Espresso Drinks  Vanilla Latte (Or Other Flavoured Latte)
# 61  Classic Espresso Drinks                Skinny Latte (Any Flavour)
#
#         Beverage_prep  Calories  Total Fat (g)  Trans Fat (g)   \
# 13  Venti Nonfat Milk       170            0.4             0.3
# 14            2% Milk       240              9             4.5
# 26            2% Milk       340             11             6.0
# 37  Venti Nonfat Milk       250            0.3             0.2
# 38            2% Milk       320              9             4.5
# 61  Venti Nonfat Milk       160            0.3             0.2
#
# ...

# %% [markdown]
# 3. เลือกข้อมูลตั้งแต่แถวที่ 50-100 ที่มีข้อมูลเพียง 3 คอลัมน์คือ  Total Fat (g), Trans Fat (g) ,Saturated Fat (g), Sodium (mg), Total Carbohydrates (g) เพื่อนำมาหาค่าสถิติพื้นฐาน

# %%
# Out:
#        Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# count       51.000000          51.000000     51.000000
# mean         2.260784           0.045098      9.019608
# std          2.180099           0.080781     10.100476
# min          0.000000           0.000000      0.000000
# 25%          0.500000           0.000000      0.000000
# 50%          1.500000           0.000000      5.000000
# 75%          3.500000           0.100000     15.000000
# max          9.000000           0.300000     35.000000
#
#         Total Carbohydrates (g)
# count                  51.000000
# mean                  131.490196
# std                    73.559873
# min                     0.000000
# 25%                    85.000000
# 50%                   120.000000
# 75%                   170.000000
# max                   330.000000

# %% [markdown]
# 4. แสดงเครื่องดื่มที่ส่วนประกอบของ Vitamin A (% DV)  20% และ Vitamin C (% DV)  0% หรือ Calcium (% DV)  20% และ Iron (% DV) 0%

# %%
# Out:
#              Beverage_category  \
# 4      Classic Espresso Drinks
# 5      Classic Espresso Drinks
# 10     Classic Espresso Drinks
# 15     Classic Espresso Drinks
# 22     Classic Espresso Drinks
# 28     Classic Espresso Drinks
# 29     Classic Espresso Drinks
# 34     Classic Espresso Drinks
# 47     Classic Espresso Drinks
# 48     Classic Espresso Drinks
# 53     Classic Espresso Drinks
# 58     Classic Espresso Drinks
# 60     Classic Espresso Drinks
# 68   Signature Espresso Drinks
# 92   Signature Espresso Drinks
# 145           Tazo® Tea Drinks
# 172                  Smoothies
#
#                                             Beverage       Beverage_prep  \
# 4                                        Caffè Latte   Short Nonfat Milk
# 5                                        Caffè Latte             2% Milk
# 10                                       Caffè Latte  Grande Nonfat Milk
# 15                                       Caffè Latte             Soymilk
# ...
